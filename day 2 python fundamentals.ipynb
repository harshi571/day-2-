# %%
variables:

Rules: no spaces
       no special characters
       it shouuld not start with number

# %%
firstname='harshi'
print(firstname)
# Out:
# harshi

# %%
nickname4='lucky'
print(nickname4)
# Out:
# lucky

# %%
Datatypes:
1.string
2.numbers- int,float
3.list
4.tuple
5.dictionary

# %%
name="syamala devi"
print(name)
# Out:
# syamala devi

# %%
#to represent the type of the variable
type(name)
# Out:
# str

# %%
#requirement 1 :to correct the format
print(name.title())
# Out:
# Syamala Devi

# %%
#requirement 2: to get the letters in upper case
print(name.upper())
# Out:
# SYAMALA DEVI

# %%
#reqirement 3: to get letters in lower case
print(name.lower())
# Out:
# syamala devi
